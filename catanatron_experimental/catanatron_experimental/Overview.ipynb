# %% [markdown]
# # Catanatron Introduction
# This shows example usage of Catanatron. First, clone the repo and install requirements.

# %%
# !pip install -r catanatron/dev-requirements.txt
# !pip install -e catanatron/catanatron_core
# !pip install -e catanatron/catanatron_server
# !pip install -e catanatron/catanatron_gym
# !pip install -e catanatron/catanatron_experimental
# exit() # Forcefully restart runtime to picks up installed requirements
# Out:
# Obtaining file:///home/alex/Masters/catanatron/catanatron_experimental/catanatron_experimental/catanatron/catanatron_core
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx in /home/alex/anaconda3/envs/catanatron/lib/python3.11/site-packages (from catanatron==3.2.1) (3.0)
# Installing collected packages: catanatron
#   Attempting uninstall: catanatron
#     Found existing installation: catanatron 3.2.1
#     Uninstalling catanatron-3.2.1:
#       Successfully uninstalled catanatron-3.2.1
#   Running setup.py develop for catanatron
# Successfully installed catanatron-3.2.1
# Obtaining file:///home/alex/Masters/catanatron/catanatron_experimental/catanatron_experimental/catanatron/catanatron_experimental
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: rich in /home/alex/anaconda3/envs/catanatron/lib/python3.11/site-packages (from catanatron_experimental==1.0.0) (13.3.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/alex/anaconda3/envs/catanatron/lib/python3.11/site-packages (from rich->catanatron_experimental==1.0.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/alex/anaconda3/envs/catanatron/lib/python3.11/site-packages (from rich->catanatron_experimental==1.0.0) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /home/alex/anaconda3/envs/catanatron/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->catanatron_experimental==1.0.0) (0.1.2)
# Installing collected packages: catanatron_experimental
#   Attempting uninstall: catanatron_experimental
#     Found existing installation: catanatron_experimental 1.0.0
#     Uninstalling catanatron_experimental-1.0.0:
#       Successfully uninstalled catanatron_experimental-1.0.0
#   Running setup.py develop for catanatron_experimental
# Successfully installed catanatron_experimental-1.0.0

# %% [markdown]
# Then, you can implement your own bot strategy and pit against some benchmark bots.

# %%
import random

from catanatron.game import Game
from catanatron.models.player import Player, RandomPlayer, Color
from catanatron.players.weighted_random import WeightedRandomPlayer
from catanatron.players.search import VictoryPointPlayer

class MyPlayer(Player):
    def decide(self, game, playable_actions):
        """Should return one of the playable_actions.

        Args:
            game (Game): complete game state. read-only.
            playable_actions (Iterable[Action]): options to choose from
        Return:
            action (Action): Chosen element of playable_actions
        """
        # ===== YOUR CODE HERE =====
        # As an example we simply choose a valid action at random:
        return random.choice(playable_actions)
        # ===== END YOUR CODE =====

# Play a simple 4v4 game. Edit MyPlayer with your logic!
players = [
    MyPlayer(Color.RED),
    WeightedRandomPlayer(Color.BLUE),
    VictoryPointPlayer(Color.WHITE),
    RandomPlayer(Color.ORANGE),
]
game = Game(players)
print(game.play())  # returns winning color
# Out:
# Color.WHITE

# %% [markdown]
# You can also simulate thousands of games to get more statistically significant results:

# %%
from pprint import pprint
from catanatron_experimental.play import play_batch

wins, results_by_player, games = play_batch(20, players)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                                       Last 10 Games
#      ╷                       ╷       ╷        ╷         ╷          ╷           ╷
#    # │ SEATING               │ TURNS │ RED VP │ BLUE VP │ WHITE VP │ ORANGE VP │ WINNER
# ╶────┼───────────────────────┼───────┼────────┼─────────┼──────────┼───────────┼────────╴
#   11 │ ORANGE,WHITE,RED,BLUE │   235 │      3 │       8 │       11 │         3 │ WHITE
#   12 │ ORANGE,RED,WHITE,BLUE │   335 │     10 │       4 │        3 │         5 │ RED
#   13 │ BLUE,ORANGE,WHITE,RED │   172 │      2 │       4 │       10 │         3 │ WHITE
#   14 │ ORANGE,BLUE,RED,WHITE │   195 │      2 │      10 │        9 │         6 │ BLUE
#   15 │ RED,WHITE,BLUE,ORANGE │   119 │      3 │       2 │       10 │         2 │ WHITE
#   16 │ BLUE,RED,ORANGE,WHITE │   366 │      8 │      10 │        2 │         9 │ BLUE
#   17 │ WHITE,BLUE,ORANGE,RED │   167 │      3 │      10 │        4 │         2 │ BLUE
#   18 │ RED,BLUE,WHITE,ORANGE │   245 │      2 │       3 │        7 │        10 │ ORANGE
#   19 │ ORANGE,RED,BLUE,WHITE │   184 │      4 │      11 │        4 │         2 │ BLUE
#   20 │ RED,WHITE,BLUE,ORANGE │   240 │      3 │      10 │        6 │         5 │ BLUE
#      ╵                       ╵       ╵        ╵         ╵          ╵           ╵
#                                               Player Summary
#                             ╷      ╷        ╷             ╷            ╷          ╷          ╷
#                             │ WINS │ AVG VP │ AVG SETTLES │ AVG CITIES │ AVG ROAD │ AVG ARMY │ AVG DEV VP
# ╶───────────────────────────┼──────┼────────┼─────────────┼────────────┼──────────┼──────────┼────────────╴
#   MyPlayer:RED              │    2 │   4.20 │        1.75 │       0.55 │     0.10 │     0.25 │       0.65
#   WeightedRandomPlayer:BLUE │    6 │   5.80 │        1.90 │       1.00 │     0.05 │     0.35 │       1.10
#   VictoryPointPlayer:WHITE  │    8 │   7.05 │        2.50 │       0.95 │     0.45 │     0.15 │       1.45
#   RandomPlayer:ORANGE       │    4 │   5.30 │        2.15 │       0.65 │     0.40 │     0.20 │       0.65
#                             ╵      ╵        ╵             ╵            ╵          ╵          ╵
#               Game Summary
#             ╷           ╷
#   AVG TICKS │ AVG TURNS │ AVG DURATION
# ╶───────────┼───────────┼──────────────╴
#      650.80 │    223.30 │   0.109 secs
#             ╵           ╵

# %% [markdown]
# You can inspect the game states in a variety of ways and compute statistics

# %%
from catanatron.json import GameEncoder
from catanatron_gym.features import create_sample_vector, create_sample
from catanatron_gym.board_tensor_features import (
    create_board_tensor,
)

game = games[-1]  # pick say the first one
# pprint(game)
# 1. Feature dictionary of last state before game ended from REDs perspective. 
#   See https://catanatron.readthedocs.io/en/latest/catanatron_gym.envs.html#catanatron_gym.envs.catanatron_env.CatanatronEnv.observation_space
#   for more information on this representation.
# record = create_sample(game, Color.RED)
# pprint(record)

# 2. Vector (similar to 1) of last state before game ended
# vector = create_sample_vector(game, Color.RED)
# print(vector)

# 3. Board Tensor representation, similar to the one described in https://arxiv.org/abs/2008.07079
# tensor = create_board_tensor(game, Color.RED)
# print(tensor.shape)
# print(tensor)

# 4. Inspect Python catanatron.state.State class
# pprint(vars(game.state))

# 5. JSON Representation (with full action history)
game_json = GameEncoder().default(game)
pprint(game_json)  # inspect a game state representation
# Out:
# {'actions': [Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=26),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(25, 26)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=30),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(29, 30)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=0),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(0, 20)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=36),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(35, 36)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=18),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(16, 18)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=32),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(11, 32)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=12),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(3, 12)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=19),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(19, 21)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 3)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 1, -1), <Color.BLUE: 'BLUE'>, 'WHEAT')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', None, None, 'ORE')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 2)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 1)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 3)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(36, 37)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 5)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 1)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='ROAD_BUILDING'),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.PLAY_ROAD_BUILDING: 'PLAY_ROAD_BUILDING'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(28, 29)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(11, 12)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 2)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((2, 0, -2), None, None)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 1)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(18, 40)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 4)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', None, None, 'WOOD')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(19, 46)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 1)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 0, 1), None, None)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 1)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 0, 0), None, None)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='YEAR_OF_PLENTY'),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.PLAY_YEAR_OF_PLENTY: 'PLAY_YEAR_OF_PLENTY'>, value=('SHEEP', 'SHEEP')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 3)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 0, 1), <Color.WHITE: 'WHITE'>, 'WOOD')),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', None, 'BRICK')),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 3)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 5)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, 1, -2), <Color.RED: 'RED'>, 'ORE')),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 3)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(3, 5)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 5)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, 0, -1), <Color.BLUE: 'BLUE'>, 'SHEEP')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 3)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', 'ORE', 'ORE', 'WOOD')),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 1)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 3)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(3, 3)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 1)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 1)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'ORE')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', None, None, 'WOOD')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 2)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 0, 0), <Color.BLUE: 'BLUE'>, 'WOOD')),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(17, 18)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(17, 39)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(38, 39)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 1)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 1)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 6)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 1, -1), <Color.RED: 'RED'>, 'SHEEP')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 4)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 3)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 2)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 3)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 2)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', None, 'SHEEP')),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 1)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'WOOD')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(45, 46)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 3)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 5)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', None, None, 'SHEEP')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', None, None, 'WHEAT')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 1)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(3, 3)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 2)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 1)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'ORE')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='KNIGHT'),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 4)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('BRICK', 'BRICK', 'BRICK', None, 'SHEEP')),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(3, 4)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.DISCARD: 'DISCARD'>, value=['SHEEP', 'WOOD', 'ORE', 'ORE', 'WOOD']),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, -1, 1), <Color.WHITE: 'WHITE'>, 'SHEEP')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 5)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'WHEAT')),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.PLAY_KNIGHT_CARD: 'PLAY_KNIGHT_CARD'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-2, 2, 0), <Color.ORANGE: 'ORANGE'>, 'BRICK')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 2)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 5)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(3, 1)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 5)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='VICTORY_POINT'),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 4)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(3, 2)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 5)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', None, None, 'BRICK')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('BRICK', 'BRICK', 'BRICK', 'BRICK', 'ORE')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 5)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 2)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, -1, 1), <Color.WHITE: 'WHITE'>, 'SHEEP')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'WOOD')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(0, 1)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 6)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(3, 5)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='VICTORY_POINT'),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 2)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 5)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 1)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(34, 35)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 4)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 1)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 2)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', None, None, 'BRICK')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 1)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, -2, 2), <Color.WHITE: 'WHITE'>, 'SHEEP')),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', None, 'ORE')),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', None, 'ORE')),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 6)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, -2, 1), None, None)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 1)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 3)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', None, None, 'WOOD')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(1, 2)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 4)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(14, 37)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 3)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'BRICK')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 4)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 1)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 4)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(37, 38)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 5)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', None, None, 'BRICK')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 1)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 6)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='VICTORY_POINT'),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='VICTORY_POINT'),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 4)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 5)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', None, None, 'ORE')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('BRICK', 'BRICK', 'BRICK', 'BRICK', 'ORE')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 3)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='KNIGHT'),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 3)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='KNIGHT'),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.PLAY_KNIGHT_CARD: 'PLAY_KNIGHT_CARD'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 1, 0), <Color.ORANGE: 'ORANGE'>, 'ORE')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 2)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 0, 0), <Color.BLUE: 'BLUE'>, 'ORE')),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 2)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.PLAY_KNIGHT_CARD: 'PLAY_KNIGHT_CARD'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 0, 1), None, None)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 3)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, 0, -1), <Color.BLUE: 'BLUE'>, 'WHEAT')),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='VICTORY_POINT'),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', 'WOOD', 'SHEEP')),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 2)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 1)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 4)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 3)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 1)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 2)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', None, 'BRICK')),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(14, 15)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 5)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', None, None, 'WOOD')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'ORE')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 2)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 5)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=32),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 4)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(15, 17)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 1)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 3)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, 1, -2), <Color.RED: 'RED'>, 'WHEAT')),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='YEAR_OF_PLENTY'),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.PLAY_YEAR_OF_PLENTY: 'PLAY_YEAR_OF_PLENTY'>, value=('WHEAT', 'ORE')),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 3)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((2, -2, 0), <Color.RED: 'RED'>, 'WOOD')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='ROAD_BUILDING'),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.PLAY_ROAD_BUILDING: 'PLAY_ROAD_BUILDING'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(19, 20)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(0, 5)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 5)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 1, -1), <Color.BLUE: 'BLUE'>, 'SHEEP')),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 1)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 1)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 6)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(3, 6)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 2)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 3)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 4)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', None, None, 'WHEAT')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 6)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.DISCARD: 'DISCARD'>, value=['WOOD', 'ORE', 'SHEEP', 'WHEAT']),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-2, 2, 0), None, None)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 1)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 5)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(3, 4)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 1, -1), <Color.RED: 'RED'>, 'ORE')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='KNIGHT'),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 3)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', None, 'BRICK')),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 4)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 2)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 4)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='KNIGHT'),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.PLAY_KNIGHT_CARD: 'PLAY_KNIGHT_CARD'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 0, 1), <Color.WHITE: 'WHITE'>, 'SHEEP')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'ORE')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 2)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(16, 21)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(21, 43)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(4, 15)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 3)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 3)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 5)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, -2, 2), <Color.WHITE: 'WHITE'>, 'WOOD')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', None, None, 'WHEAT')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 1)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 1)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 5)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.PLAY_KNIGHT_CARD: 'PLAY_KNIGHT_CARD'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((2, 0, -2), None, None)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 2)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='KNIGHT'),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 5)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 4)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='KNIGHT'),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.PLAY_KNIGHT_CARD: 'PLAY_KNIGHT_CARD'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, -1, 1), <Color.WHITE: 'WHITE'>, 'WOOD')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(24, 25)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 6)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 2)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 3)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 6)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='MONOPOLY'),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.PLAY_MONOPOLY: 'PLAY_MONOPOLY'>, value='SHEEP'),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'BRICK')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 6)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', 'ORE', 'ORE', 'BRICK')),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(12, 13)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 2)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 2)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(3, 6)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', None, None, 'BRICK')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('BRICK', 'BRICK', 'BRICK', 'BRICK', 'SHEEP')),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 4)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.PLAY_KNIGHT_CARD: 'PLAY_KNIGHT_CARD'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 0, 0), None, None)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(4, 1)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', None, None, 'SHEEP')),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(5, 4)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', None, 'ORE')),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 1)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 4)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 4)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 1)),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', 'ORE', None, 'WOOD')),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', None, 'ORE')),
#              Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(6, 4)),
#              Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(2, 2)),
#              Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=(1, 4)),
#              Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value='KNIGHT'),
# ...
#                 'direction': 'SOUTH',
#                 'id': 65,
#                 'tile_coordinate': (-1, -2, 3)},
#            66: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHEAST',
#                 'id': 66,
#                 'tile_coordinate': (-2, -1, 3)},
#            67: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTH',
#                 'id': 67,
#                 'tile_coordinate': (-2, -1, 3)},
#            68: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHEAST',
#                 'id': 68,
#                 'tile_coordinate': (-3, 0, 3)},
#            69: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTH',
#                 'id': 69,
#                 'tile_coordinate': (-3, 0, 3)},
#            70: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHWEST',
#                 'id': 70,
#                 'tile_coordinate': (-3, 0, 3)},
#            71: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTH',
#                 'id': 71,
#                 'tile_coordinate': (-3, 1, 2)},
#            72: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHWEST',
#                 'id': 72,
#                 'tile_coordinate': (-3, 1, 2)},
#            73: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTH',
#                 'id': 73,
#                 'tile_coordinate': (-3, 2, 1)},
#            74: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHWEST',
#                 'id': 74,
#                 'tile_coordinate': (-3, 2, 1)},
#            75: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTH',
#                 'id': 75,
#                 'tile_coordinate': (-3, 3, 0)},
#            76: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHWEST',
#                 'id': 76,
#                 'tile_coordinate': (-2, 3, -1)},
#            77: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHWEST',
#                 'id': 77,
#                 'tile_coordinate': (-3, 3, 0)},
#            78: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHWEST',
#                 'id': 78,
#                 'tile_coordinate': (-3, 3, 0)},
#            79: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHWEST',
#                 'id': 79,
#                 'tile_coordinate': (-1, 3, -2)},
#            80: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHWEST',
#                 'id': 80,
#                 'tile_coordinate': (-2, 3, -1)},
#            81: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHWEST',
#                 'id': 81,
#                 'tile_coordinate': (0, 3, -3)},
#            82: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHWEST',
#                 'id': 82,
#                 'tile_coordinate': (-1, 3, -2)},
#            83: {'building': None,
#                 'color': None,
#                 'direction': 'NORTH',
#                 'id': 83,
#                 'tile_coordinate': (0, 3, -3)},
#            84: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHWEST',
#                 'id': 84,
#                 'tile_coordinate': (1, 2, -3)},
#            85: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHWEST',
#                 'id': 85,
#                 'tile_coordinate': (0, 3, -3)},
#            86: {'building': None,
#                 'color': None,
#                 'direction': 'NORTH',
#                 'id': 86,
#                 'tile_coordinate': (1, 2, -3)},
#            87: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHWEST',
#                 'id': 87,
#                 'tile_coordinate': (2, 1, -3)},
#            88: {'building': None,
#                 'color': None,
#                 'direction': 'NORTH',
#                 'id': 88,
#                 'tile_coordinate': (2, 1, -3)},
#            89: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHWEST',
#                 'id': 89,
#                 'tile_coordinate': (3, 0, -3)},
#            90: {'building': None,
#                 'color': None,
#                 'direction': 'NORTH',
#                 'id': 90,
#                 'tile_coordinate': (3, 0, -3)},
#            91: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHEAST',
#                 'id': 91,
#                 'tile_coordinate': (3, 0, -3)},
#            92: {'building': None,
#                 'color': None,
#                 'direction': 'NORTH',
#                 'id': 92,
#                 'tile_coordinate': (3, -1, -2)},
#            93: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHEAST',
#                 'id': 93,
#                 'tile_coordinate': (3, -1, -2)},
#            94: {'building': None,
#                 'color': None,
#                 'direction': 'NORTH',
#                 'id': 94,
#                 'tile_coordinate': (3, -2, -1)},
#            95: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHEAST',
#                 'id': 95,
#                 'tile_coordinate': (3, -2, -1)}},
#  'player_state': {'P0_ACTUAL_VICTORY_POINTS': 3,
#                   'P0_BRICK_IN_HAND': 1,
#                   'P0_CITIES_AVAILABLE': 4,
#                   'P0_HAS_ARMY': False,
#                   'P0_HAS_PLAYED_DEVELOPMENT_CARD_IN_TURN': False,
#                   'P0_HAS_ROAD': False,
#                   'P0_HAS_ROLLED': False,
#                   'P0_KNIGHT_IN_HAND': 0,
#                   'P0_LONGEST_ROAD_LENGTH': 4,
#                   'P0_MONOPOLY_IN_HAND': 0,
#                   'P0_ORE_IN_HAND': 2,
#                   'P0_PLAYED_KNIGHT': 2,
#                   'P0_PLAYED_MONOPOLY': 1,
#                   'P0_PLAYED_ROAD_BUILDING': 0,
#                   'P0_PLAYED_VICTORY_POINT': 0,
#                   'P0_PLAYED_YEAR_OF_PLENTY': 0,
#                   'P0_ROADS_AVAILABLE': 7,
#                   'P0_ROAD_BUILDING_IN_HAND': 0,
#                   'P0_SETTLEMENTS_AVAILABLE': 3,
#                   'P0_SHEEP_IN_HAND': 0,
#                   'P0_VICTORY_POINTS': 2,
#                   'P0_VICTORY_POINT_IN_HAND': 1,
#                   'P0_WHEAT_IN_HAND': 0,
#                   'P0_WOOD_IN_HAND': 0,
#                   'P0_YEAR_OF_PLENTY_IN_HAND': 0,
#                   'P1_ACTUAL_VICTORY_POINTS': 6,
#                   'P1_BRICK_IN_HAND': 0,
#                   'P1_CITIES_AVAILABLE': 3,
#                   'P1_HAS_ARMY': False,
#                   'P1_HAS_PLAYED_DEVELOPMENT_CARD_IN_TURN': False,
#                   'P1_HAS_ROAD': False,
#                   'P1_HAS_ROLLED': False,
#                   'P1_KNIGHT_IN_HAND': 0,
#                   'P1_LONGEST_ROAD_LENGTH': 2,
#                   'P1_MONOPOLY_IN_HAND': 0,
#                   'P1_ORE_IN_HAND': 2,
#                   'P1_PLAYED_KNIGHT': 2,
#                   'P1_PLAYED_MONOPOLY': 0,
#                   'P1_PLAYED_ROAD_BUILDING': 1,
#                   'P1_PLAYED_VICTORY_POINT': 0,
#                   'P1_PLAYED_YEAR_OF_PLENTY': 1,
#                   'P1_ROADS_AVAILABLE': 10,
#                   'P1_ROAD_BUILDING_IN_HAND': 0,
#                   'P1_SETTLEMENTS_AVAILABLE': 3,
#                   'P1_SHEEP_IN_HAND': 0,
#                   'P1_VICTORY_POINTS': 4,
#                   'P1_VICTORY_POINT_IN_HAND': 2,
#                   'P1_WHEAT_IN_HAND': 0,
#                   'P1_WOOD_IN_HAND': 2,
#                   'P1_YEAR_OF_PLENTY_IN_HAND': 0,
#                   'P2_ACTUAL_VICTORY_POINTS': 10,
#                   'P2_BRICK_IN_HAND': 0,
#                   'P2_CITIES_AVAILABLE': 1,
#                   'P2_HAS_ARMY': True,
#                   'P2_HAS_PLAYED_DEVELOPMENT_CARD_IN_TURN': False,
#                   'P2_HAS_ROAD': False,
#                   'P2_HAS_ROLLED': True,
#                   'P2_KNIGHT_IN_HAND': 0,
#                   'P2_LONGEST_ROAD_LENGTH': 4,
#                   'P2_MONOPOLY_IN_HAND': 0,
#                   'P2_ORE_IN_HAND': 0,
#                   'P2_PLAYED_KNIGHT': 10,
#                   'P2_PLAYED_MONOPOLY': 1,
#                   'P2_PLAYED_ROAD_BUILDING': 1,
#                   'P2_PLAYED_VICTORY_POINT': 0,
#                   'P2_PLAYED_YEAR_OF_PLENTY': 1,
#                   'P2_ROADS_AVAILABLE': 8,
#                   'P2_ROAD_BUILDING_IN_HAND': 0,
#                   'P2_SETTLEMENTS_AVAILABLE': 5,
#                   'P2_SHEEP_IN_HAND': 7,
#                   'P2_VICTORY_POINTS': 8,
#                   'P2_VICTORY_POINT_IN_HAND': 2,
#                   'P2_WHEAT_IN_HAND': 1,
#                   'P2_WOOD_IN_HAND': 0,
#                   'P2_YEAR_OF_PLENTY_IN_HAND': 0,
#                   'P3_ACTUAL_VICTORY_POINTS': 5,
#                   'P3_BRICK_IN_HAND': 2,
#                   'P3_CITIES_AVAILABLE': 4,
#                   'P3_HAS_ARMY': False,
#                   'P3_HAS_PLAYED_DEVELOPMENT_CARD_IN_TURN': False,
#                   'P3_HAS_ROAD': True,
#                   'P3_HAS_ROLLED': False,
#                   'P3_KNIGHT_IN_HAND': 0,
#                   'P3_LONGEST_ROAD_LENGTH': 10,
#                   'P3_MONOPOLY_IN_HAND': 0,
#                   'P3_ORE_IN_HAND': 2,
#                   'P3_PLAYED_KNIGHT': 0,
#                   'P3_PLAYED_MONOPOLY': 0,
#                   'P3_PLAYED_ROAD_BUILDING': 0,
#                   'P3_PLAYED_VICTORY_POINT': 0,
#                   'P3_PLAYED_YEAR_OF_PLENTY': 0,
#                   'P3_ROADS_AVAILABLE': 0,
#                   'P3_ROAD_BUILDING_IN_HAND': 0,
#                   'P3_SETTLEMENTS_AVAILABLE': 2,
#                   'P3_SHEEP_IN_HAND': 1,
#                   'P3_VICTORY_POINTS': 5,
#                   'P3_VICTORY_POINT_IN_HAND': 0,
#                   'P3_WHEAT_IN_HAND': 0,
#                   'P3_WOOD_IN_HAND': 3,
#                   'P3_YEAR_OF_PLENTY_IN_HAND': 0},
#  'robber_coordinate': (0, 1, -1),
#  'tiles': [{'coordinate': (0, 0, 0),
#             'tile': {'id': 0,
#                      'number': 3,
#                      'resource': 'ORE',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (1, -1, 0),
#             'tile': {'id': 1,
#                      'number': 8,
#                      'resource': 'WHEAT',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (0, -1, 1),
#             'tile': {'id': 2,
#                      'number': 10,
#                      'resource': 'WOOD',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (-1, 0, 1),
#             'tile': {'id': 3,
#                      'number': 8,
#                      'resource': 'ORE',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (-1, 1, 0),
#             'tile': {'id': 4,
#                      'number': 5,
#                      'resource': 'WOOD',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (0, 1, -1),
#             'tile': {'id': 5,
#                      'number': 10,
#                      'resource': 'WHEAT',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (1, 0, -1),
#             'tile': {'id': 6,
#                      'number': 4,
#                      'resource': 'ORE',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (2, -2, 0),
#             'tile': {'id': 7,
#                      'number': 9,
#                      'resource': 'BRICK',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (1, -2, 1),
#             'tile': {'id': 8,
#                      'number': 9,
#                      'resource': 'SHEEP',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (0, -2, 2),
#             'tile': {'id': 9,
#                      'number': 6,
#                      'resource': 'SHEEP',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (-1, -1, 2),
#             'tile': {'id': 10,
#                      'number': 12,
#                      'resource': 'WHEAT',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (-2, 0, 2), 'tile': {'id': 11, 'type': 'DESERT'}},
#            {'coordinate': (-2, 1, 1),
#             'tile': {'id': 12,
#                      'number': 11,
#                      'resource': 'WOOD',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (-2, 2, 0),
#             'tile': {'id': 13,
#                      'number': 6,
#                      'resource': 'BRICK',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (-1, 2, -1),
#             'tile': {'id': 14,
#                      'number': 3,
#                      'resource': 'WOOD',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (0, 2, -2),
#             'tile': {'id': 15,
#                      'number': 4,
#                      'resource': 'SHEEP',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (1, 1, -2),
#             'tile': {'id': 16,
#                      'number': 11,
#                      'resource': 'WHEAT',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (2, 0, -2),
#             'tile': {'id': 17,
#                      'number': 5,
#                      'resource': 'SHEEP',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (2, -1, -1),
#             'tile': {'id': 18,
#                      'number': 2,
#                      'resource': 'BRICK',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (3, -3, 0),
#             'tile': {'direction': 'WEST',
#                      'id': 0,
#                      'resource': 'WHEAT',
#                      'type': 'PORT'}},
#            {'coordinate': (2, -3, 1), 'tile': {'type': 'WATER'}},
#            {'coordinate': (1, -3, 2),
#             'tile': {'direction': 'NORTHWEST',
#                      'id': 1,
#                      'resource': None,
#                      'type': 'PORT'}},
#            {'coordinate': (0, -3, 3), 'tile': {'type': 'WATER'}},
#            {'coordinate': (-1, -2, 3),
#             'tile': {'direction': 'NORTHWEST',
#                      'id': 2,
#                      'resource': 'ORE',
#                      'type': 'PORT'}},
#            {'coordinate': (-2, -1, 3), 'tile': {'type': 'WATER'}},
#            {'coordinate': (-3, 0, 3),
#             'tile': {'direction': 'NORTHEAST',
#                      'id': 3,
#                      'resource': None,
#                      'type': 'PORT'}},
#            {'coordinate': (-3, 1, 2), 'tile': {'type': 'WATER'}},
#            {'coordinate': (-3, 2, 1),
#             'tile': {'direction': 'EAST',
#                      'id': 4,
#                      'resource': 'SHEEP',
#                      'type': 'PORT'}},
#            {'coordinate': (-3, 3, 0), 'tile': {'type': 'WATER'}},
#            {'coordinate': (-2, 3, -1),
#             'tile': {'direction': 'EAST',
#                      'id': 5,
#                      'resource': None,
#                      'type': 'PORT'}},
#            {'coordinate': (-1, 3, -2), 'tile': {'type': 'WATER'}},
#            {'coordinate': (0, 3, -3),
#             'tile': {'direction': 'SOUTHEAST',
#                      'id': 6,
#                      'resource': 'WOOD',
#                      'type': 'PORT'}},
#            {'coordinate': (1, 2, -3), 'tile': {'type': 'WATER'}},
#            {'coordinate': (2, 1, -3),
#             'tile': {'direction': 'SOUTHWEST',
#                      'id': 7,
#                      'resource': None,
#                      'type': 'PORT'}},
#            {'coordinate': (3, 0, -3), 'tile': {'type': 'WATER'}},
#            {'coordinate': (3, -1, -2),
#             'tile': {'direction': 'SOUTHWEST',
#                      'id': 8,
#                      'resource': 'BRICK',
#                      'type': 'PORT'}},
#            {'coordinate': (3, -2, -1), 'tile': {'type': 'WATER'}}],
#  'winning_color': <Color.BLUE: 'BLUE'>}

# %% [markdown]
# ## Testing The Random Player Behavours

# %%
import random
from pprint import pprint
from catanatron_experimental.play import play_batch
from catanatron.game import Game
from catanatron.models.player import Player, RandomPlayer, Color
from catanatron.players.weighted_random import WeightedRandomPlayer, CityRandomPlayer, SettlementRandomPlayer, LongestRoadRandomPlayer, DevCardRandomPlayer 
from catanatron.players.search import VictoryPointPlayer
from typing import Literal

# %%
# Play a simple 4v4 game. Edit MyPlayer with your logic!
players = [
    CityRandomPlayer(Color.RED),
    SettlementRandomPlayer(Color.BLUE),
    LongestRoadRandomPlayer(Color.WHITE),
    DevCardRandomPlayer(Color.ORANGE),
]
game = Game(players,seed=42)
print(game.play())
# Out:
# Color.ORANGE

# %%
my_game_config = {
    "discard_limit": 7,
    "vps_to_win": 10,
    "catan_map": "BASE",
    # "map_type":"BASE"
}

wins, results_by_player, games = play_batch(40, players)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                                       Last 10 Games
#      ╷                       ╷       ╷        ╷         ╷          ╷           ╷
#    # │ SEATING               │ TURNS │ RED VP │ BLUE VP │ WHITE VP │ ORANGE VP │ WINNER
# ╶────┼───────────────────────┼───────┼────────┼─────────┼──────────┼───────────┼────────╴
#   31 │ BLUE,WHITE,ORANGE,RED │   373 │     10 │       7 │        6 │         9 │ RED
#   32 │ WHITE,BLUE,ORANGE,RED │   205 │     10 │       5 │        3 │         8 │ RED
#   33 │ WHITE,RED,ORANGE,BLUE │   181 │      2 │      10 │        4 │         7 │ BLUE
#   34 │ RED,ORANGE,WHITE,BLUE │   220 │      3 │       4 │       10 │         3 │ WHITE
#   35 │ RED,ORANGE,WHITE,BLUE │   447 │      9 │       5 │        6 │        10 │ ORANGE
#   36 │ ORANGE,WHITE,BLUE,RED │   416 │      7 │      10 │        2 │         7 │ BLUE
#   37 │ RED,ORANGE,WHITE,BLUE │   607 │      9 │       4 │        9 │        10 │ ORANGE
#   38 │ ORANGE,WHITE,BLUE,RED │   264 │      4 │      10 │        4 │         5 │ BLUE
#   39 │ BLUE,RED,ORANGE,WHITE │   213 │      6 │       4 │       10 │         2 │ WHITE
#   40 │ WHITE,ORANGE,RED,BLUE │   380 │     10 │       6 │        5 │         2 │ RED
#      ╵                       ╵       ╵        ╵         ╵          ╵           ╵
#                                                 Player Summary
#                                 ╷      ╷        ╷             ╷            ╷          ╷          ╷
#                                 │ WINS │ AVG VP │ AVG SETTLES │ AVG CITIES │ AVG ROAD │ AVG ARMY │ AVG DEV VP
# ╶───────────────────────────────┼──────┼────────┼─────────────┼────────────┼──────────┼──────────┼────────────╴
#   CityRandomPlayer:RED          │   11 │   5.72 │        1.68 │       1.77 │     0.25 │     0.00 │       0.00
#   SettlementRandomPlayer:BLUE   │   10 │   5.95 │        2.80 │       1.35 │     0.23 │     0.00 │       0.00
#   LongestRoadRandomPlayer:WHITE │    9 │   5.88 │        2.58 │       0.35 │     0.38 │     0.35 │       1.15
#   DevCardRandomPlayer:ORANGE    │   10 │   6.22 │        1.93 │       0.70 │     0.15 │     0.50 │       1.60
#                                 ╵      ╵        ╵             ╵            ╵          ╵          ╵
#               Game Summary
#             ╷           ╷
#   AVG TICKS │ AVG TURNS │ AVG DURATION
# ╶───────────┼───────────┼──────────────╴
#      959.83 │    325.23 │   0.048 secs
#             ╵           ╵

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
#
# NVIDIA GeForce GTX 1060 6GB
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB
