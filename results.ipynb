# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = [
    ["group(n=5)", 1.1,],
    ["group(n=9)", 0.98],
    ["group(n=14)", 0.53]
]
df = pd.DataFrame(data=data,columns=["group","MSEv"])
df
# Out:
#          group  MSEv
# 0   group(n=5)  1.10
# 1   group(n=9)  0.98
# 2  group(n=14)  0.53

# %%
sns.barplot(data=df, x='group',y='MSEv',palette='tab10')
plt.title("MSEv of different groups")
plt.xlabel("Feature Groupings")
# Out:
# /tmp/ipykernel_401306/2965684163.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='group',y='MSEv',palette='tab10')
# Text(0.5, 0, 'Feature Groupings')

# %%
# TODO: Add summary plot and timeline for all 3 groups
group_3 = './cluster_data/shapley_data/group_3/sample_250/shapley_values_group_3.csv'
group_2 = './cluster_data/shapley_data/group_2/sample_350/shapley_values_group_2.csv'
group_1 = './cluster_data/shapley_data/small_strat/sample_50/shapley_values_small_strat.csv'

# %%
df_g1 = pd.read_csv(group_1)
df_g2 = pd.read_csv(group_2)
df_g3 = pd.read_csv(group_3)

df_g1.drop(columns=['none', 'Unnamed: 0'],axis=1,inplace=True)
df_g2.drop(columns=['none', 'Unnamed: 0'],axis=1,inplace=True)
df_g3.drop(columns=['none', 'Unnamed: 0'],axis=1,inplace=True)

df_g3
# Out:
#     board_features  graph_features  turn_features    p0_vps    p1_vps
# 0         0.111917       -0.198618       0.158665  0.829901  0.473645
# 1         0.211710       -0.179391       0.198888  0.718519  0.425784
# 2         0.240656       -0.152277       0.206683  0.648825  0.431624
# 3         0.136010       -0.157752       0.192830  0.539161  0.665261
# 4         0.047738       -0.061564       0.198783  0.738933  0.451621
# 5         0.190626       -0.030126      -0.128497  0.810950  0.532557
# 6         0.047738       -0.061564       0.198783  0.738933  0.451621
# 7         0.191707       -0.026004      -0.141185  0.880271  0.470721
# 8        -0.031952       -0.555988       0.221606  0.017223 -0.275379
# 9         0.002569       -0.288370      -0.156097  0.128769 -0.311360
# 10       -0.007661       -0.328600       0.192773 -0.341180 -0.139822
# 11       -0.043282       -0.124009      -0.152554 -0.146197 -0.158447
# 12       -0.056371       -0.249182       0.183038 -0.209097 -0.292877
# 13       -0.136203       -0.010321      -0.128869 -0.000107 -0.348989
# 14        0.044098        0.040267       0.188784  0.755821  0.346540
# 15       -0.015455        0.076027      -0.132956  1.033668  0.414225
# 16       -0.137262        0.055704       0.169343  1.049713  0.238011
# 17       -0.192749        0.127912      -0.114656  1.278043  0.276959
# 18        0.281532        0.012490       0.278662  0.462394  0.340432
# 19        0.305091        0.052868      -0.056377  0.658844  0.415084
# 20        0.203009        0.015426       0.249120  0.644211  0.263745
# 21        0.052211       -0.176560      -0.743943  0.267138 -0.023336
# 22       -0.045398        0.069740      -0.121302  0.988546  0.483924
# 23       -0.191279        0.063338       0.200042  0.976460  0.326949
# 24       -0.180372        0.091476      -0.127505  1.254545  0.337367
# 25       -0.268477        0.071831       0.191388  1.257982  0.122786
# 26       -0.086071        0.188144      -0.119760  1.348286  0.044911
# 27       -0.228267        0.038627       0.182378  0.908337  0.474434
# 28        0.017827        0.040543      -0.225740  1.027343  0.515538
# 29        0.043934        0.054794      -0.113851  0.886181  0.504452
# 30       -0.054618        0.023557       0.177897  0.881444  0.347230
# 31        0.160748        0.028824      -0.236607  0.985916  0.436630
# 32       -0.407681        0.191948      -0.168788  0.894289  0.865743
# 33       -0.562503        0.248952       0.218852  0.932654  0.537556
# 34       -1.407754        0.237424      -0.433147  0.269139 -0.290151
# 35        0.071837        0.104575      -0.099471  1.183178  0.115392
# 36       -0.330433       -0.068140       0.176155  1.246591  0.351337
# 37       -0.353370        0.026019      -0.112596  1.609646  0.205811
# 38       -0.210321       -0.017365       0.166153  0.911921  0.525122
# 39       -0.280275        0.044240      -0.123137  1.353622  0.381060
# 40        0.108439       -0.031751       0.220779  0.650380  0.427664
# 41        0.139616        0.029274      -0.103518  1.125398  0.184740
# 42        0.106313       -0.036451       0.172931  0.860066  0.272651
# 43        0.091471        0.041722      -0.141802  1.233490  0.150629
# 44        0.066891       -0.041965       0.189158  0.663723  0.497705
# 45        0.043366       -0.081202      -0.231146  0.846383  0.798109
# 46        0.192267       -0.072617      -0.138570  0.915116  0.479315
# 47        0.111646       -0.135601       0.197883  1.171701  0.029881
# 48        0.167896       -0.060021      -0.163826  1.629800 -0.198339
# 49        0.227451        0.046211       0.607095  0.886045 -0.391293
# 50       -0.180427       -0.039690      -0.187297  0.174472 -1.391548
# 51       -0.221306       -0.114174       0.234366 -0.694041 -0.829333
# 52       -0.330886       -0.177764      -0.153818 -0.674585 -0.287438
# 53       -0.482678       -0.217852       0.114750 -0.610659 -0.428051
# 54       -0.147908        0.133148      -0.137269 -0.754826 -0.717635

# %%
g1_sum = df_g1.abs().mean().sort_values(ascending=False)
sns.barplot(x=g1_sum.values,y=g1_sum.index,palette='tab10')
plt.title("Group n=14")
plt.ylabel('Feature Groups')
plt.xlabel('|Mean Shapley Value|')
# Out:
# /tmp/ipykernel_401306/3018325700.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=g1_sum.values,y=g1_sum.index,palette='tab10')
# Text(0.5, 0, '|Mean Shapley Value|')

# %%
g1_sum = df_g2.abs().mean().sort_values(ascending=False)
sns.barplot(x=g1_sum.values,y=g1_sum.index,palette='tab10')
plt.title("Group n=9")
plt.ylabel('Feature Groups')
plt.xlabel('|Mean Shapley Value|')
# Out:
# /tmp/ipykernel_401306/4276074892.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=g1_sum.values,y=g1_sum.index,palette='tab10')
# Text(0.5, 0, '|Mean Shapley Value|')

# %%
g1_sum = df_g3.abs().mean().sort_values(ascending=False)
sns.barplot(x=g1_sum.values,y=g1_sum.index,palette='tab10')
plt.title("Group n=5")
plt.ylabel('Feature Groups')
plt.xlabel('|Mean Shapley Value|')
# Out:
# /tmp/ipykernel_401306/3287968636.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=g1_sum.values,y=g1_sum.index,palette='tab10')
# Text(0.5, 0, '|Mean Shapley Value|')

# %%
plt.figure(figsize=(12, 6))

for column in df_g3.columns:
    plt.plot(df_g3.index, df_g3[column].abs(), label=column)

plt.xlabel("Index")
plt.ylabel("Row Value")
plt.title("Multi-line Plot of Each Column")
plt.legend(title="Columns", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

for column in df_g2.columns:
    plt.plot(df_g2.index, df_g2[column].abs(), label=column)

plt.xlabel("Index")
plt.ylabel("Row Value")
plt.title("Multi-line Plot of Each Column")
plt.legend(title="Columns", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

for column in df_g1.columns:
    plt.plot(df_g1.index, df_g1[column].abs(), label=column)

plt.xlabel("Index")
plt.ylabel("Row Value")
plt.title("Multi-line Plot of Each Column")
plt.legend(title="Columns", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
